# %%
import faceutils
import cv2
from matplotlib import pyplot as plt

# %%
# load image
image = cv2.imread('input.jpg')

# %%
crop = faceutils.crop_stylegan(image)

# %%
# show image with crop (doesnt actually show with cv2, use PIL)
plt.imshow(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
