# %%
import pandas as pd

df = pd.read_csv('test/eeg.csv')
df.head()
# Out:
#     0delta_1   0delta_2   0delta_3   0delta_4   0theta_1   0theta_2  \
# 0   2.305404  10.958996  19.968119  10.234467  20.847082  13.248531
# 1   0.065355  16.680924  11.983496  29.172618  38.561894  23.209259
# 2  10.859276  15.964214  19.316199  20.274477  37.919899  24.540579
# 3   4.202393   2.242094   6.391706   4.976684  26.271364  15.684171
# 4   7.559430   9.129417   7.460826   3.795788  15.863443   9.749102
#
#     0theta_3   0theta_4   0alpha_1   0alpha_2  ...   4beta_10   4beta_11  \
# 0   9.664706  12.649077  12.309391  11.437869  ...  27.452234  24.783627
# 1  10.523048   0.586952   7.167132   7.897561  ...  19.587617  11.545434
# 2  13.831832   3.740500  23.690369   3.055898  ...  24.879700  26.463682
# 3   7.456746  11.797998  37.827131  14.305961  ...  15.592365   8.648167
# 4  10.194671  14.292124  15.576518  17.128639  ...  15.968743  16.694833
#
#     4beta_12   4beta_13   4beta_14   4beta_15   4beta_16   4beta_17  \
# ...

# %%
for column in df.columns:
    print(column)
# Out:
# 0delta_1
# 0delta_2
# 0delta_3
# 0delta_4
# 0theta_1
# 0theta_2
# 0theta_3
# 0theta_4
# 0alpha_1
# 0alpha_2
# 0alpha_3
# 0alpha_4
# 0beta_1
# 0beta_2
# 0beta_3
# 0beta_4
# 0beta_5
# 0beta_6
# 0beta_7
# 0beta_8
# 0beta_9
# 0beta_10
# 0beta_11
# 0beta_12
# 0beta_13
# 0beta_14
# 0beta_15
# 0beta_16
# 0beta_17
# 0beta_18
# 0timestamp
# 1delta_1
# 1delta_2
# 1delta_3
# 1delta_4
# 1theta_1
# 1theta_2
# 1theta_3
# 1theta_4
# 1alpha_1
# 1alpha_2
# 1alpha_3
# 1alpha_4
# 1beta_1
# 1beta_2
# 1beta_3
# 1beta_4
# 1beta_5
# 1beta_6
# 1beta_7
# 1beta_8
# 1beta_9
# 1beta_10
# 1beta_11
# 1beta_12
# 1beta_13
# 1beta_14
# 1beta_15
# 1beta_16
# 1beta_17
# 1beta_18
# 1timestamp
# 2delta_1
# 2delta_2
# 2delta_3
# 2delta_4
# 2theta_1
# 2theta_2
# 2theta_3
# 2theta_4
# 2alpha_1
# 2alpha_2
# 2alpha_3
# 2alpha_4
# 2beta_1
# 2beta_2
# 2beta_3
# 2beta_4
# 2beta_5
# 2beta_6
# 2beta_7
# 2beta_8
# 2beta_9
# 2beta_10
# 2beta_11
# 2beta_12
# 2beta_13
# 2beta_14
# 2beta_15
# 2beta_16
# 2beta_17
# 2beta_18
# ...
